# %%
# !pip install pytesseract opencv-python

import cv2
import pytesseract
import numpy as np
from sklearn.cluster import DBSCAN
import math
# Out:
# Requirement already satisfied: pytesseract in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (0.3.10)
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (4.9.0.80)
# Requirement already satisfied: packaging>=21.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pytesseract) (10.0.1)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (1.26.4)
# [notice] A new release of pip is available: 23.3.2 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import pytesseract
import numpy as np
from sklearn.cluster import DBSCAN
import math

# Function to perform OCR and get bounding boxes
def ocr_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"Image at path {image_path} could not be loaded.")
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    d = pytesseract.image_to_data(gray, output_type=pytesseract.Output.DICT)

    predictions = []
    for i in range(len(d['text'])):
        if int(d['conf'][i]) > 0:  # Consider only confident predictions
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            predictions.append((d['text'][i], ((x, y), (x + w, y + h))))
    return predictions

def get_distance(predictions):
    """
    Function returns dictionary with (key,value):
        * text : detected text in image
        * center_x : center of bounding box (x)
        * center_y : center of bounding box (y)
        * distance_from_origin : hypotenuse
        * distance_y : distance between y and origin (0,0)
    """
    # Point of origin
    x0, y0 = 0, 0

    # Generate dictionary
    detections = []
    for group in predictions:
        # Get center point of bounding box
        top_left_x, top_left_y = group[1][0]
        bottom_right_x, bottom_right_y = group[1][1]
        center_x, center_y = (top_left_x + bottom_right_x)/2, (top_left_y + bottom_right_y)/2

        # Use the Pythagorean Theorem to solve for distance from origin
        distance_from_origin = math.dist([x0,y0], [center_x, center_y])

        # Calculate difference between y and origin to get unique rows
        distance_y = center_y - y0

        # Append all results
        detections.append({
                            'text': group[0],
                            'center_x': center_x,
                            'center_y': center_y,
                            'distance_from_origin': distance_from_origin,
                            'distance_y': distance_y
                        })

    return detections

def calculate_average_distances(detections):
    """
    Calculate average vertical and horizontal distances between bounding boxes.
    """
    vertical_distances = []
    horizontal_distances = []

    for i in range(len(detections) - 1):
        for j in range(i + 1, len(detections)):
            vertical_distances.append(abs(detections[i]['center_y'] - detections[j]['center_y']))
            horizontal_distances.append(abs(detections[i]['center_x'] - detections[j]['center_x']))

    avg_vertical_distance = np.mean(vertical_distances)
    avg_horizontal_distance = np.mean(horizontal_distances)

    return avg_vertical_distance, avg_horizontal_distance

def cluster_predictions(detections, avg_vertical_distance, avg_horizontal_distance):
    """
    Clusters detections using DBSCAN clustering algorithm with dynamic eps.
    """
    coords = np.array([[det['center_x'], det['center_y']] for det in detections])
    eps = (avg_vertical_distance + avg_horizontal_distance) / 2
    clustering = DBSCAN(eps=eps, min_samples=1).fit(coords)
    clusters = []
    for label in set(clustering.labels_):
        cluster = [detections[i] for i in range(len(detections)) if clustering.labels_[i] == label]
        clusters.append(cluster)
    return clusters

def order_clusters(clusters):
    """
    Orders clusters from top to bottom, and within each cluster, from left to right.
    """
    ordered_clusters = sorted(clusters, key=lambda cluster: cluster[0]['center_y'])
    for cluster in ordered_clusters:
        cluster.sort(key=lambda x: x['center_x'])
    return ordered_clusters

def extract_text_from_clusters(clusters):
    """
    Extracts and concatenates text from ordered clusters.
    """
    ordered_text = []
    for cluster in clusters:
        line_text = ' '.join([det['text'] for det in cluster])
        ordered_text.append(line_text)
    return ' '.join(ordered_text)

# Example usage with your predictions
image_path = 'Nitrofurantoin1.jpg' # Replace with your image path
try:
    predictions = ocr_image(image_path)
    detections = get_distance(predictions)
    avg_vertical_distance, avg_horizontal_distance = calculate_average_distances(detections)
    clusters = cluster_predictions(detections, avg_vertical_distance, avg_horizontal_distance)
    ordered_clusters = order_clusters(clusters)
    extracted_text = extract_text_from_clusters(ordered_clusters)

    print(f'Extracted Text: {extracted_text}')
except FileNotFoundError as e:
    print(e)
# Out:
# Extracted Text:      4 8     m.Each Mfg. "ach bie <i Store LG Colour capsule UTITROY ae      equivalent Sue: Nitrofurantoin Lic. Nitrofurantoin : * tard hard below shell. No. to to Approved sage : gelatin gelatin IP 30°C, IP i UTITROY Nitrofurante Nitrofurantoin 37/UA/2006 capsu 4 colour protect ay) le Nitrofurantoin St, (Hydrous/Anhydrous) Behe USEC used from 100 ee | contains if in      mg. light. ei. UTITROY.-UTITROY : #4) J ite   Ppp   ee ~   Sara Trolkaa ee GiOMila Leen Dehradun-248197, P   Industrial      UTITROY   Capsules fa Estate, Ls Se   ey UTITROY Uttarakhand, ere USP Ltd. India  UTITROY 3 5 © 7s ee) =< w wm wo — = © 2) DATE-DEC-23 MFG. DATE-JAN-22 EXP, CAP. 0 M,R.P,RS,88,16 INCL, TAXES/1 ALL

# %%
import cv2
import pytesseract
import numpy as np
from sklearn.cluster import DBSCAN
import math
import matplotlib.pyplot as plt

# Function to perform OCR and get bounding boxes
def ocr_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"Image at path {image_path} could not be loaded.")
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    d = pytesseract.image_to_data(gray, output_type=pytesseract.Output.DICT)

    predictions = []
    for i in range(len(d['text'])):
        if int(d['conf'][i]) > 0:  # Consider only confident predictions
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            predictions.append((d['text'][i], ((x, y), (x + w, y + h))))
    return predictions

image_path = 'Nitrofurantoin1.jpg'  # Replace with your image path
try:
    predictions = ocr_image(image_path)
    print("OCR Predictions:")
    for pred in predictions:
        print(pred)
except FileNotFoundError as e:
    print(e)
# Out:
# OCR Predictions:
# ('    ', ((0, 0), (499, 532)))
# (' ', ((1002, 0), (1914, 218)))
# ('bie', ((121, 221), (230, 254)))
# ('i', ((595, 241), (600, 249)))
# ('le', ((879, 234), (936, 299)))
# ('contains', ((966, 247), (1259, 309)))
# (':', ((1291, 267), (1301, 312)))
# ('"ach', ((94, 261), (255, 338)))
# ('hard', ((282, 254), (410, 319)))
# ('gelatin', ((435, 245), (643, 324)))
# ('capsu', ((673, 248), (870, 310)))
# ('4', ((60, 319), (86, 379)))
# ('Nitrofurantoin', ((107, 348), (510, 430)))
# ('IP', ((543, 342), (603, 402)))
# ('(Hydrous/Anhydrous)', ((632, 337), (1375, 435)))
# ('equivalent', ((104, 455), (408, 537)))
# ('to', ((432, 454), (487, 508)))
# ('Nitrofurantoin', ((517, 441), (973, 505)))
# ('100', ((1009, 447), (1134, 560)))
# ('mg.', ((1162, 466), (1285, 530)))
# ('Colour', ((106, 561), (297, 625)))
# (':', ((326, 571), (329, 611)))
# ('Approved', ((352, 544), (660, 623)))
# ('colour', ((691, 540), (902, 603)))
# ('used', ((929, 550), (1094, 609)))
# ('in', ((1127, 567), (1179, 612)))
# (' ', ((1554, 256), (2874, 554)))
# ('Leen', ((1585, 567), (2004, 681)))
# ('capsule', ((100, 656), (328, 731)))
# ('shell.', ((354, 649), (511, 710)))
# ('|', ((1101, 749), (1107, 754)))
# ('GiOMila', ((1554, 653), (2008, 731)))
# ('3', ((2826, 777), (2863, 822)))
# ('<i', ((97, 759), (254, 817)))
# ('Behe', ((899, 744), (1111, 827)))
# ('ei.', ((1159, 740), (1295, 904)))
# ('Trolkaa', ((1554, 768), (1804, 897)))
# ('ere', ((2296, 849), (2417, 907)))
# ('Ltd.', ((2447, 850), (2575, 933)))
# ('Store', ((96, 857), (259, 915)))
# ('below', ((285, 853), (461, 913)))
# ('30°C,', ((488, 846), (664, 917)))
# ('protect', ((695, 848), (934, 922)))
# ('from', ((957, 849), (1115, 914)))
# ('light.', ((1147, 855), (1306, 933)))
# ('Sara', ((1555, 915), (1690, 965)))
# ('Industrial', ((1716, 917), (1974, 969)))
# ('Estate,', ((2001, 922), (2197, 981)))
# ('5', ((2827, 915), (2869, 1013)))
# ('Mfg.', ((98, 955), (225, 1029)))
# ('Lic.', ((254, 956), (353, 1012)))
# ('No.', ((383, 953), (483, 1011)))
# (':', ((517, 967), (524, 1008)))
# ('37/UA/2006', ((555, 947), (956, 1010)))
# ('Dehradun-248197,', ((1558, 984), (2098, 1048)))
# ('Uttarakhand,', ((2126, 964), (2494, 1055)))
# ('India', ((2522, 1000), (2660, 1050)))
# ('©', ((2830, 1020), (2869, 1063)))
# ('UTITROY', ((107, 1068), (378, 1120)))
# ('UTITROY', ((477, 1064), (771, 1117)))
# ('UTITROY.-UTITROY', ((879, 1065), (1623, 1155)))
# ('UTITROY', ((1728, 1082), (2040, 1157)))
# ('UTITROY', ((2145, 1087), (2456, 1141)))
# (' UTITROY', ((2561, 1094), (2874, 1148)))
# ('*', ((293, 1173), (371, 1271)))
# ('Nitrofurantoin', ((430, 1147), (1478, 1465)))
# ('Capsules', ((1539, 1164), (2258, 1501)))
# ('USP', ((2302, 1223), (2648, 1396)))
# (' ', ((0, 1464), (2846, 1702)))
# ('    ', ((0, 1702), (101, 2083)))
# (' ', ((831, 1702), (2846, 1799)))
# (' ', ((857, 1799), (2882, 1899)))
# ('m.Each', ((4, 1751), (257, 1813)))
# ('tard', ((264, 1700), (414, 1820)))
# ('gelatin', ((443, 1767), (653, 1839)))
# ('Nitrofurantoin', ((62, 1849), (520, 1945)))
# ('IP', ((552, 1868), (612, 1926)))
# ('8', ((61, 1936), (102, 1995)))
# ('ae', ((65, 1944), (421, 2111)))
# ('to', ((443, 1966), (498, 2023)))
# ('Nitrofurante', ((528, 1966), (916, 2057)))
# ('if', ((1132, 2094), (1160, 2133)))
# ('J', ((1405, 2123), (1408, 2124)))
# ('~', ((1530, 2120), (1536, 2128)))
# ('P', ((1830, 2139), (1831, 2142)))
# ('Se', ((2130, 2144), (2188, 2151)))
# ('ey', ((2209, 2143), (2269, 2157)))
# ('LG', ((79, 2037), (310, 2230)))
# ('Sue:', ((223, 2063), (344, 2147)))
# ('sage', ((365, 2058), (666, 2224)))
# ('ay)', ((694, 2069), (942, 2229)))
# ('USEC', ((937, 2110), (1073, 2133)))
# ('ite', ((1266, 2135), (1568, 2183)))
# ('Ls', ((1984, 2157), (2293, 2208)))
# ('4', ((764, 2175), (796, 2232)))
# ('St,', ((926, 2189), (985, 2213)))
# ('ee', ((1078, 2191), (1123, 2225)))
# ('#4)', ((1330, 2196), (1359, 2232)))
# ('Ppp', ((1422, 2198), (1474, 2240)))
# ('ee', ((1491, 2212), (1546, 2233)))
# ('ee', ((1743, 2243), (1745, 2247)))
# ('fa', ((1996, 2225), (2006, 2257)))
# ('  ', ((857, 1899), (2888, 2000)))
# (' ', ((902, 2000), (2888, 2083)))
# (' ', ((870, 2083), (2357, 2206)))
# ('    ', ((0, 2206), (2357, 2288)))
# ('   ', ((0, 2083), (194, 2261)))
# (' ', ((3180, 0), (3584, 260)))
# ('0', ((3252, 730), (3313, 768)))
# ('CAP.', ((3250, 567), (3311, 709)))
# ('DATE-DEC-23', ((3177, 579), (3245, 1026)))
# ('EXP,', ((3189, 1049), (3253, 1181)))
# ('M,R.P,RS,88,16', ((3256, 1435), (3317, 1950)))
# ('INCL,', ((3255, 781), (3322, 1411)))
# ('ALL', ((3249, 1072), (3331, 1175)))
# ('TAXES/1', ((3255, 781), (3322, 1039)))
# ('7s', ((3012, 1859), (3083, 1935)))
# ('©', ((3125, 1490), (3183, 1527)))
# ('wm', ((3122, 1536), (3181, 1569)))
# ('w', ((3121, 1578), (3181, 1613)))
# ('wo', ((3122, 1622), (3182, 1657)))
# ('—', ((3123, 1668), (3181, 1698)))
# ('=', ((3123, 1703), (3182, 1746)))
# ('2)', ((3135, 1790), (3178, 1825)))
# ('=<', ((3122, 1836), (3176, 1873)))
# ('ee)', ((3123, 1907), (3173, 1947)))
# ('MFG.', ((3191, 1782), (3246, 1949)))
# ('DATE-JAN-22', ((3190, 1310), (3251, 1758)))
# ('', ((3010, 1983), (3584, 2288)))

# %%
def get_distance(predictions):
    """
    Function returns dictionary with (key,value):
        * text : detected text in image
        * center_x : center of bounding box (x)
        * center_y : center of bounding box (y)
        * distance_from_origin : hypotenuse
        * distance_y : distance between y and origin (0,0)
    """
    # Point of origin
    x0, y0 = 0, 0

    # Generate dictionary
    detections = []
    for group in predictions:
        # Get center point of bounding box
        top_left_x, top_left_y = group[1][0]
        bottom_right_x, bottom_right_y = group[1][1]
        center_x, center_y = (top_left_x + bottom_right_x)/2, (top_left_y + bottom_right_y)/2

        # Use the Pythagorean Theorem to solve for distance from origin
        distance_from_origin = math.dist([x0,y0], [center_x, center_y])

        # Calculate difference between y and origin to get unique rows
        distance_y = center_y - y0

        # Append all results
        detections.append({
                            'text': group[0],
                            'center_x': center_x,
                            'center_y': center_y,
                            'distance_from_origin': distance_from_origin,
                            'distance_y': distance_y
                        })

    return detections

detections = get_distance(predictions)
print("Detections with distances:")
for det in detections:
    print(det)
# Out:
# Detections with distances:
# {'text': '    ', 'center_x': 249.5, 'center_y': 266.0, 'distance_from_origin': 364.7002193583108, 'distance_y': 266.0}
# {'text': ' ', 'center_x': 1458.0, 'center_y': 109.0, 'distance_from_origin': 1462.068739834075, 'distance_y': 109.0}
# {'text': 'bie', 'center_x': 175.5, 'center_y': 237.5, 'distance_from_origin': 295.3074668883264, 'distance_y': 237.5}
# {'text': 'i', 'center_x': 597.5, 'center_y': 245.0, 'distance_from_origin': 645.7795676544745, 'distance_y': 245.0}
# {'text': 'le', 'center_x': 907.5, 'center_y': 266.5, 'distance_from_origin': 945.8216005146002, 'distance_y': 266.5}
# {'text': 'contains', 'center_x': 1112.5, 'center_y': 278.0, 'distance_from_origin': 1146.7084415839975, 'distance_y': 278.0}
# {'text': ':', 'center_x': 1296.0, 'center_y': 289.5, 'distance_from_origin': 1327.9406048464668, 'distance_y': 289.5}
# {'text': '"ach', 'center_x': 174.5, 'center_y': 299.5, 'distance_from_origin': 346.62732148519393, 'distance_y': 299.5}
# {'text': 'hard', 'center_x': 346.0, 'center_y': 286.5, 'distance_from_origin': 449.2196010861503, 'distance_y': 286.5}
# {'text': 'gelatin', 'center_x': 539.0, 'center_y': 284.5, 'distance_from_origin': 609.4762095439, 'distance_y': 284.5}
# {'text': 'capsu', 'center_x': 771.5, 'center_y': 279.0, 'distance_from_origin': 820.3982264729733, 'distance_y': 279.0}
# {'text': '4', 'center_x': 73.0, 'center_y': 349.0, 'distance_from_origin': 356.5529413705628, 'distance_y': 349.0}
# {'text': 'Nitrofurantoin', 'center_x': 308.5, 'center_y': 389.0, 'distance_from_origin': 496.4808656937345, 'distance_y': 389.0}
# {'text': 'IP', 'center_x': 573.0, 'center_y': 372.0, 'distance_from_origin': 683.1639627497926, 'distance_y': 372.0}
# {'text': '(Hydrous/Anhydrous)', 'center_x': 1003.5, 'center_y': 386.0, 'distance_from_origin': 1075.178241037271, 'distance_y': 386.0}
# {'text': 'equivalent', 'center_x': 256.0, 'center_y': 496.0, 'distance_from_origin': 558.1684333603971, 'distance_y': 496.0}
# {'text': 'to', 'center_x': 459.5, 'center_y': 481.0, 'distance_from_origin': 665.207674339375, 'distance_y': 481.0}
# {'text': 'Nitrofurantoin', 'center_x': 745.0, 'center_y': 473.0, 'distance_from_origin': 882.4703961040279, 'distance_y': 473.0}
# {'text': '100', 'center_x': 1071.5, 'center_y': 503.5, 'distance_from_origin': 1183.902234139289, 'distance_y': 503.5}
# {'text': 'mg.', 'center_x': 1223.5, 'center_y': 498.0, 'distance_from_origin': 1320.9679216392803, 'distance_y': 498.0}
# {'text': 'Colour', 'center_x': 201.5, 'center_y': 593.0, 'distance_from_origin': 626.2996487305418, 'distance_y': 593.0}
# {'text': ':', 'center_x': 327.5, 'center_y': 591.0, 'distance_from_origin': 675.6754028377827, 'distance_y': 591.0}
# {'text': 'Approved', 'center_x': 506.0, 'center_y': 583.5, 'distance_from_origin': 772.3394655201818, 'distance_y': 583.5}
# {'text': 'colour', 'center_x': 796.5, 'center_y': 571.5, 'distance_from_origin': 980.3185706697594, 'distance_y': 571.5}
# {'text': 'used', 'center_x': 1011.5, 'center_y': 579.5, 'distance_from_origin': 1165.7411805370864, 'distance_y': 579.5}
# {'text': 'in', 'center_x': 1153.0, 'center_y': 589.5, 'distance_from_origin': 1294.9591692404822, 'distance_y': 589.5}
# {'text': ' ', 'center_x': 2214.0, 'center_y': 405.0, 'distance_from_origin': 2250.7378790076823, 'distance_y': 405.0}
# {'text': 'Leen', 'center_x': 1794.5, 'center_y': 624.0, 'distance_from_origin': 1899.8963787533255, 'distance_y': 624.0}
# {'text': 'capsule', 'center_x': 214.0, 'center_y': 693.5, 'distance_from_origin': 725.7673525310986, 'distance_y': 693.5}
# {'text': 'shell.', 'center_x': 432.5, 'center_y': 679.5, 'distance_from_origin': 805.4666349390271, 'distance_y': 679.5}
# {'text': '|', 'center_x': 1104.0, 'center_y': 751.5, 'distance_from_origin': 1335.5029951295505, 'distance_y': 751.5}
# {'text': 'GiOMila', 'center_x': 1781.0, 'center_y': 692.0, 'distance_from_origin': 1910.7132176231994, 'distance_y': 692.0}
# {'text': '3', 'center_x': 2844.5, 'center_y': 799.5, 'distance_from_origin': 2954.7217297065386, 'distance_y': 799.5}
# {'text': '<i', 'center_x': 175.5, 'center_y': 788.0, 'distance_from_origin': 807.3067880304241, 'distance_y': 788.0}
# {'text': 'Behe', 'center_x': 1005.0, 'center_y': 785.5, 'distance_from_origin': 1275.5529193255763, 'distance_y': 785.5}
# {'text': 'ei.', 'center_x': 1227.0, 'center_y': 822.0, 'distance_from_origin': 1476.8930225307452, 'distance_y': 822.0}
# {'text': 'Trolkaa', 'center_x': 1679.0, 'center_y': 832.5, 'distance_from_origin': 1874.0590305537337, 'distance_y': 832.5}
# {'text': 'ere', 'center_x': 2356.5, 'center_y': 878.0, 'distance_from_origin': 2514.7517273082844, 'distance_y': 878.0}
# {'text': 'Ltd.', 'center_x': 2511.0, 'center_y': 891.5, 'distance_from_origin': 2664.562487538996, 'distance_y': 891.5}
# {'text': 'Store', 'center_x': 177.5, 'center_y': 886.0, 'distance_from_origin': 903.6051405342934, 'distance_y': 886.0}
# {'text': 'below', 'center_x': 373.0, 'center_y': 883.0, 'distance_from_origin': 958.5499465338256, 'distance_y': 883.0}
# {'text': '30°C,', 'center_x': 576.0, 'center_y': 881.5, 'distance_from_origin': 1053.0043922035652, 'distance_y': 881.5}
# {'text': 'protect', 'center_x': 814.5, 'center_y': 885.0, 'distance_from_origin': 1202.7615100259902, 'distance_y': 885.0}
# {'text': 'from', 'center_x': 1036.0, 'center_y': 881.5, 'distance_from_origin': 1360.2713883633662, 'distance_y': 881.5}
# {'text': 'light.', 'center_x': 1226.5, 'center_y': 894.0, 'distance_from_origin': 1517.7411669978515, 'distance_y': 894.0}
# {'text': 'Sara', 'center_x': 1622.5, 'center_y': 940.0, 'distance_from_origin': 1875.128328941782, 'distance_y': 940.0}
# {'text': 'Industrial', 'center_x': 1845.0, 'center_y': 943.0, 'distance_from_origin': 2072.0217180328973, 'distance_y': 943.0}
# {'text': 'Estate,', 'center_x': 2099.0, 'center_y': 951.5, 'distance_from_origin': 2304.593944711302, 'distance_y': 951.5}
# {'text': '5', 'center_x': 2848.0, 'center_y': 964.0, 'distance_from_origin': 3006.725793949292, 'distance_y': 964.0}
# {'text': 'Mfg.', 'center_x': 161.5, 'center_y': 992.0, 'distance_from_origin': 1005.06032157279, 'distance_y': 992.0}
# {'text': 'Lic.', 'center_x': 303.5, 'center_y': 984.0, 'distance_from_origin': 1029.7418365784697, 'distance_y': 984.0}
# {'text': 'No.', 'center_x': 433.0, 'center_y': 982.0, 'distance_from_origin': 1073.2255121827845, 'distance_y': 982.0}
# {'text': ':', 'center_x': 520.5, 'center_y': 987.5, 'distance_from_origin': 1116.277967174843, 'distance_y': 987.5}
# {'text': '37/UA/2006', 'center_x': 755.5, 'center_y': 978.5, 'distance_from_origin': 1236.221056284029, 'distance_y': 978.5}
# {'text': 'Dehradun-248197,', 'center_x': 1828.0, 'center_y': 1016.0, 'distance_from_origin': 2091.3727549148193, 'distance_y': 1016.0}
# {'text': 'Uttarakhand,', 'center_x': 2310.0, 'center_y': 1009.5, 'distance_from_origin': 2520.950267260344, 'distance_y': 1009.5}
# {'text': 'India', 'center_x': 2591.0, 'center_y': 1025.0, 'distance_from_origin': 2786.378653377893, 'distance_y': 1025.0}
# {'text': '©', 'center_x': 2849.5, 'center_y': 1041.5, 'distance_from_origin': 3033.870877278728, 'distance_y': 1041.5}
# {'text': 'UTITROY', 'center_x': 242.5, 'center_y': 1094.0, 'distance_from_origin': 1120.5544386597198, 'distance_y': 1094.0}
# {'text': 'UTITROY', 'center_x': 624.0, 'center_y': 1090.5, 'distance_from_origin': 1256.4100644296034, 'distance_y': 1090.5}
# {'text': 'UTITROY.-UTITROY', 'center_x': 1251.0, 'center_y': 1110.0, 'distance_from_origin': 1672.4535867999446, 'distance_y': 1110.0}
# {'text': 'UTITROY', 'center_x': 1884.0, 'center_y': 1119.5, 'distance_from_origin': 2191.514601822219, 'distance_y': 1119.5}
# {'text': 'UTITROY', 'center_x': 2300.5, 'center_y': 1114.0, 'distance_from_origin': 2556.031347616848, 'distance_y': 1114.0}
# {'text': ' UTITROY', 'center_x': 2717.5, 'center_y': 1121.0, 'distance_from_origin': 2939.6338632557627, 'distance_y': 1121.0}
# {'text': '*', 'center_x': 332.0, 'center_y': 1222.0, 'distance_from_origin': 1266.2969635910842, 'distance_y': 1222.0}
# {'text': 'Nitrofurantoin', 'center_x': 954.0, 'center_y': 1306.0, 'distance_from_origin': 1617.3286617135059, 'distance_y': 1306.0}
# {'text': 'Capsules', 'center_x': 1898.5, 'center_y': 1332.5, 'distance_from_origin': 2319.452198257166, 'distance_y': 1332.5}
# {'text': 'USP', 'center_x': 2475.0, 'center_y': 1309.5, 'distance_from_origin': 2800.0741508038677, 'distance_y': 1309.5}
# {'text': ' ', 'center_x': 1423.0, 'center_y': 1583.0, 'distance_from_origin': 2128.5718216682285, 'distance_y': 1583.0}
# {'text': '    ', 'center_x': 50.5, 'center_y': 1892.5, 'distance_from_origin': 1893.1736581729633, 'distance_y': 1892.5}
# {'text': ' ', 'center_x': 1838.5, 'center_y': 1750.5, 'distance_from_origin': 2538.5689866537014, 'distance_y': 1750.5}
# {'text': ' ', 'center_x': 1869.5, 'center_y': 1849.0, 'distance_from_origin': 2629.4165227289495, 'distance_y': 1849.0}
# {'text': 'm.Each', 'center_x': 130.5, 'center_y': 1782.0, 'distance_from_origin': 1786.7720195928746, 'distance_y': 1782.0}
# {'text': 'tard', 'center_x': 339.0, 'center_y': 1760.0, 'distance_from_origin': 1792.3506911316213, 'distance_y': 1760.0}
# {'text': 'gelatin', 'center_x': 548.0, 'center_y': 1803.0, 'distance_from_origin': 1884.4397045275819, 'distance_y': 1803.0}
# {'text': 'Nitrofurantoin', 'center_x': 291.0, 'center_y': 1897.0, 'distance_from_origin': 1919.1899332791427, 'distance_y': 1897.0}
# {'text': 'IP', 'center_x': 582.0, 'center_y': 1897.0, 'distance_from_origin': 1984.2714028075898, 'distance_y': 1897.0}
# {'text': '8', 'center_x': 81.5, 'center_y': 1965.5, 'distance_from_origin': 1967.1889843123868, 'distance_y': 1965.5}
# {'text': 'ae', 'center_x': 243.0, 'center_y': 2027.5, 'distance_from_origin': 2042.010100366793, 'distance_y': 2027.5}
# {'text': 'to', 'center_x': 470.5, 'center_y': 1994.5, 'distance_from_origin': 2049.2438849487876, 'distance_y': 1994.5}
# {'text': 'Nitrofurante', 'center_x': 722.0, 'center_y': 2011.5, 'distance_from_origin': 2137.151433567589, 'distance_y': 2011.5}
# {'text': 'if', 'center_x': 1146.0, 'center_y': 2113.5, 'distance_from_origin': 2404.2042862452436, 'distance_y': 2113.5}
# {'text': 'J', 'center_x': 1406.5, 'center_y': 2123.5, 'distance_from_origin': 2547.056045712383, 'distance_y': 2123.5}
# {'text': '~', 'center_x': 1533.0, 'center_y': 2124.0, 'distance_from_origin': 2619.439825611575, 'distance_y': 2124.0}
# {'text': 'P', 'center_x': 1830.5, 'center_y': 2140.5, 'distance_from_origin': 2816.4641840435324, 'distance_y': 2140.5}
# {'text': 'Se', 'center_x': 2159.0, 'center_y': 2147.5, 'distance_from_origin': 3045.166210570451, 'distance_y': 2147.5}
# {'text': 'ey', 'center_x': 2239.0, 'center_y': 2150.0, 'distance_from_origin': 3104.129668683317, 'distance_y': 2150.0}
# {'text': 'LG', 'center_x': 194.5, 'center_y': 2133.5, 'distance_from_origin': 2142.347427472958, 'distance_y': 2133.5}
# {'text': 'Sue:', 'center_x': 283.5, 'center_y': 2105.0, 'distance_from_origin': 2124.005002348158, 'distance_y': 2105.0}
# {'text': 'sage', 'center_x': 515.5, 'center_y': 2141.0, 'distance_from_origin': 2202.185562117779, 'distance_y': 2141.0}
# {'text': 'ay)', 'center_x': 818.0, 'center_y': 2149.0, 'distance_from_origin': 2299.4184047275953, 'distance_y': 2149.0}
# {'text': 'USEC', 'center_x': 1005.0, 'center_y': 2121.5, 'distance_from_origin': 2347.506602759617, 'distance_y': 2121.5}
# {'text': 'ite', 'center_x': 1417.0, 'center_y': 2159.0, 'distance_from_origin': 2582.4736203880184, 'distance_y': 2159.0}
# {'text': 'Ls', 'center_x': 2138.5, 'center_y': 2182.5, 'distance_from_origin': 3055.566805029797, 'distance_y': 2182.5}
# {'text': '4', 'center_x': 780.0, 'center_y': 2203.5, 'distance_from_origin': 2337.4798929616486, 'distance_y': 2203.5}
# {'text': 'St,', 'center_x': 955.5, 'center_y': 2201.0, 'distance_from_origin': 2399.4543650588566, 'distance_y': 2201.0}
# {'text': 'ee', 'center_x': 1100.5, 'center_y': 2208.0, 'distance_from_origin': 2467.055785749483, 'distance_y': 2208.0}
# {'text': '#4)', 'center_x': 1344.5, 'center_y': 2214.0, 'distance_from_origin': 2590.265671702422, 'distance_y': 2214.0}
# {'text': 'Ppp', 'center_x': 1448.0, 'center_y': 2219.0, 'distance_from_origin': 2649.653750964454, 'distance_y': 2219.0}
# {'text': 'ee', 'center_x': 1518.5, 'center_y': 2222.5, 'distance_from_origin': 2691.7185031128347, 'distance_y': 2222.5}
# {'text': 'ee', 'center_x': 1744.0, 'center_y': 2245.0, 'distance_from_origin': 2842.808646391804, 'distance_y': 2245.0}
# {'text': 'fa', 'center_x': 2001.0, 'center_y': 2241.0, 'distance_from_origin': 3004.343855153734, 'distance_y': 2241.0}
# {'text': '  ', 'center_x': 1872.5, 'center_y': 1949.5, 'distance_from_origin': 2703.110523082621, 'distance_y': 1949.5}
# {'text': ' ', 'center_x': 1895.0, 'center_y': 2041.5, 'distance_from_origin': 2785.452790840297, 'distance_y': 2041.5}
# {'text': ' ', 'center_x': 1613.5, 'center_y': 2144.5, 'distance_from_origin': 2683.7031318683516, 'distance_y': 2144.5}
# {'text': '    ', 'center_x': 1178.5, 'center_y': 2247.0, 'distance_from_origin': 2537.296050917196, 'distance_y': 2247.0}
# {'text': '   ', 'center_x': 97.0, 'center_y': 2172.0, 'distance_from_origin': 2174.1648971501677, 'distance_y': 2172.0}
# {'text': ' ', 'center_x': 3382.0, 'center_y': 130.0, 'distance_from_origin': 3384.4975993491266, 'distance_y': 130.0}
# {'text': '0', 'center_x': 3282.5, 'center_y': 749.0, 'distance_from_origin': 3366.8690574478837, 'distance_y': 749.0}
# {'text': 'CAP.', 'center_x': 3280.5, 'center_y': 638.0, 'distance_from_origin': 3341.964130567532, 'distance_y': 638.0}
# {'text': 'DATE-DEC-23', 'center_x': 3211.0, 'center_y': 802.5, 'distance_from_origin': 3309.7624159446855, 'distance_y': 802.5}
# {'text': 'EXP,', 'center_x': 3221.0, 'center_y': 1115.0, 'distance_from_origin': 3408.528421474581, 'distance_y': 1115.0}
# {'text': 'M,R.P,RS,88,16', 'center_x': 3286.5, 'center_y': 1692.5, 'distance_from_origin': 3696.706439521537, 'distance_y': 1692.5}
# {'text': 'INCL,', 'center_x': 3288.5, 'center_y': 1096.0, 'distance_from_origin': 3466.330660799688, 'distance_y': 1096.0}
# {'text': 'ALL', 'center_x': 3290.0, 'center_y': 1123.5, 'distance_from_origin': 3476.543146575345, 'distance_y': 1123.5}
# {'text': 'TAXES/1', 'center_x': 3288.5, 'center_y': 910.0, 'distance_from_origin': 3412.086202017763, 'distance_y': 910.0}
# {'text': '7s', 'center_x': 3047.5, 'center_y': 1897.0, 'distance_from_origin': 3589.6887399884686, 'distance_y': 1897.0}
# {'text': '©', 'center_x': 3154.0, 'center_y': 1508.5, 'distance_from_origin': 3496.181953216966, 'distance_y': 1508.5}
# {'text': 'wm', 'center_x': 3151.5, 'center_y': 1552.5, 'distance_from_origin': 3513.147947354338, 'distance_y': 1552.5}
# {'text': 'w', 'center_x': 3151.0, 'center_y': 1595.5, 'distance_from_origin': 3531.9146719591063, 'distance_y': 1595.5}
# {'text': 'wo', 'center_x': 3152.0, 'center_y': 1639.5, 'distance_from_origin': 3552.8951926562654, 'distance_y': 1639.5}
# {'text': '—', 'center_x': 3152.0, 'center_y': 1683.0, 'distance_from_origin': 3573.176877793765, 'distance_y': 1683.0}
# {'text': '=', 'center_x': 3152.5, 'center_y': 1724.5, 'distance_from_origin': 3593.3489254454544, 'distance_y': 1724.5}
# {'text': '2)', 'center_x': 3156.5, 'center_y': 1807.5, 'distance_from_origin': 3637.3820943090377, 'distance_y': 1807.5}
# {'text': '=<', 'center_x': 3149.0, 'center_y': 1854.5, 'distance_from_origin': 3654.5001368176195, 'distance_y': 1854.5}
# {'text': 'ee)', 'center_x': 3148.0, 'center_y': 1927.0, 'distance_from_origin': 3690.9664046154635, 'distance_y': 1927.0}
# {'text': 'MFG.', 'center_x': 3218.5, 'center_y': 1865.5, 'distance_from_origin': 3720.0581312662307, 'distance_y': 1865.5}
# {'text': 'DATE-JAN-22', 'center_x': 3220.5, 'center_y': 1534.0, 'distance_from_origin': 3567.1804341804745, 'distance_y': 1534.0}
# {'text': '', 'center_x': 3297.0, 'center_y': 2135.5, 'distance_from_origin': 3928.176326235878, 'distance_y': 2135.5}

# %%
def calculate_average_distances(detections):
    """
    Calculate average vertical and horizontal distances between bounding boxes.
    """
    vertical_distances = []
    horizontal_distances = []

    for i in range(len(detections) - 1):
        for j in range(i + 1, len(detections)):
            vertical_distances.append(abs(detections[i]['center_y'] - detections[j]['center_y']))
            horizontal_distances.append(abs(detections[i]['center_x'] - detections[j]['center_x']))

    avg_vertical_distance = np.mean(vertical_distances)
    avg_horizontal_distance = np.mean(horizontal_distances)

    return avg_vertical_distance, avg_horizontal_distance

avg_vertical_distance, avg_horizontal_distance = calculate_average_distances(detections)
print(f"Average Vertical Distance: {avg_vertical_distance}")
print(f"Average Horizontal Distance: {avg_horizontal_distance}")
# Out:
# Average Vertical Distance: 769.2113614341085
# Average Horizontal Distance: 1207.281734496124

# %%
def cluster_predictions(detections, avg_vertical_distance, avg_horizontal_distance):
    """
    Clusters detections using DBSCAN clustering algorithm with dynamic eps.
    """
    coords = np.array([[det['center_x'], det['center_y']] for det in detections])
    eps = (avg_vertical_distance + avg_horizontal_distance) / 2 * 6  # Adjusting the eps factor for better clustering
    clustering = DBSCAN(eps=eps, min_samples=1).fit(coords)
    clusters = []
    for label in set(clustering.labels_):
        cluster = [detections[i] for i in range(len(detections)) if clustering.labels_[i] == label]
        clusters.append(cluster)
    return clusters

clusters = cluster_predictions(detections, avg_vertical_distance, avg_horizontal_distance)
print("Clusters formed:")
for cluster in clusters:
    print([det['text'] for det in cluster])
# Out:
# Clusters formed:
# ['    ', ' ', 'bie', 'i', 'le', 'contains', ':', '"ach', 'hard', 'gelatin', 'capsu', '4', 'Nitrofurantoin', 'IP', '(Hydrous/Anhydrous)', 'equivalent', 'to', 'Nitrofurantoin', '100', 'mg.', 'Colour', ':', 'Approved', 'colour', 'used', 'in', ' ', 'Leen', 'capsule', 'shell.', '|', 'GiOMila', '3', '<i', 'Behe', 'ei.', 'Trolkaa', 'ere', 'Ltd.', 'Store', 'below', '30°C,', 'protect', 'from', 'light.', 'Sara', 'Industrial', 'Estate,', '5', 'Mfg.', 'Lic.', 'No.', ':', '37/UA/2006', 'Dehradun-248197,', 'Uttarakhand,', 'India', '©', 'UTITROY', 'UTITROY', 'UTITROY.-UTITROY', 'UTITROY', 'UTITROY', ' UTITROY', '*', 'Nitrofurantoin', 'Capsules', 'USP', ' ', '    ', ' ', ' ', 'm.Each', 'tard', 'gelatin', 'Nitrofurantoin', 'IP', '8', 'ae', 'to', 'Nitrofurante', 'if', 'J', '~', 'P', 'Se', 'ey', 'LG', 'Sue:', 'sage', 'ay)', 'USEC', 'ite', 'Ls', '4', 'St,', 'ee', '#4)', 'Ppp', 'ee', 'ee', 'fa', '  ', ' ', ' ', '    ', '   ', ' ', '0', 'CAP.', 'DATE-DEC-23', 'EXP,', 'M,R.P,RS,88,16', 'INCL,', 'ALL', 'TAXES/1', '7s', '©', 'wm', 'w', 'wo', '—', '=', '2)', '=<', 'ee)', 'MFG.', 'DATE-JAN-22', '']

# %%
def visualize_clusters(image_path, clusters):
    image = cv2.imread(image_path)
    colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0), (0, 255, 255), (255, 0, 255)]
    
    for idx, cluster in enumerate(clusters):
        color = colors[idx % len(colors)]
        for det in cluster:
            top_left = (int(det['center_x'] - 100), int(det['center_y'] - 100))  # Adjust as needed
            bottom_right = (int(det['center_x'] + 20), int(det['center_y'] + 10))  # Adjust as needed
            cv2.rectangle(image, top_left, bottom_right, color, 2)
    
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()

visualize_clusters(image_path, clusters)

# %%
def order_clusters(clusters):
    """
    Orders clusters from top to bottom, and within each cluster, from left to right.
    """
    ordered_clusters = sorted(clusters, key=lambda cluster: cluster[0]['center_y'])
    for cluster in ordered_clusters:
        cluster.sort(key=lambda x: x['center_x'])
    return ordered_clusters

def extract_text_from_clusters(clusters):
    """
    Extracts and concatenates text from ordered clusters.
    """
    ordered_text = []
    for cluster in clusters:
        line_text = ' '.join([det['text'] for det in cluster])
        ordered_text.append(line_text)
    return ' '.join(ordered_text)

ordered_clusters = order_clusters(clusters)
extracted_text = extract_text_from_clusters(ordered_clusters)

print(f'Extracted Text: {extracted_text}')
# Out:
# Extracted Text:      4 8     m.Each Mfg. "ach bie <i Store LG Colour capsule UTITROY ae      equivalent Sue: Nitrofurantoin Lic. Nitrofurantoin : * tard hard below shell. No. to to Approved sage : gelatin gelatin IP 30°C, IP i UTITROY Nitrofurante Nitrofurantoin 37/UA/2006 capsu 4 colour protect ay) le Nitrofurantoin St, (Hydrous/Anhydrous) Behe USEC used from 100 ee | contains if in      mg. light. ei. UTITROY.-UTITROY : #4) J ite   Ppp   ee ~   Sara Trolkaa ee GiOMila Leen Dehradun-248197, P   Industrial      UTITROY   Capsules fa Estate, Ls Se   ey UTITROY Uttarakhand, ere USP Ltd. India  UTITROY 3 5 © 7s ee) =< w wm wo — = © 2) DATE-DEC-23 MFG. DATE-JAN-22 EXP, CAP. 0 M,R.P,RS,88,16 INCL, TAXES/1 ALL

# %%
import re

extracted_text = """
4 8 m.Each Mfg. "ach bie <i Store LG Colour capsule UTITROY ae equivalent Sue: Nitrofurantoin Lic. Nitrofurantoin : * tard hard below shell. No. to to Approved sage : gelatin gelatin IP 30°C, IP i UTITROY Nitrofurante Nitrofurantoin 37/UA/2006 capsu 4 colour protect ay) le Nitrofurantoin St, (Hydrous/Anhydrous) Behe USEC used from 100 ee | contains if in mg. light. ei. UTITROY.-UTITROY : #4) J ite Ppp ee ~ Sara Trolkaa ee GiOMila Leen Dehradun-248197, P Industrial UTITROY Capsules fa Estate, Ls Se ey UTITROY Uttarakhand, ere USP Ltd. India UTITROY 3 5 © 7s ee) =< w wm wo — = © 2) DATE-DEC-23 MFG. DATE-JAN-22 EXP, CAP. 0 M,R.P,RS,88,16 INCL, TAXES/1 ALL
"""

# Extract tablet name
tablet_name_match = re.search(r'\b[A-Z][A-Za-z\s]*\s*Capsules\s*USP\b', extracted_text)
tablet_name = tablet_name_match.group(0) if tablet_name_match else "Not found"

# Extract dosage
dosage_match = re.search(r'\b\d+\s*mg\b', extracted_text)
dosage = dosage_match.group(0) if dosage_match else "As prescribed"

# Extract manufacturing date
mfg_date_match = re.search(r'\bDATE-([A-Za-z]+-\d{2})\s*MFG\.', extracted_text)
mfg_date = mfg_date_match.group(1).strip() if mfg_date_match else "Not found"

# Extract expiry date
expiry_date_match = re.search(r'\bDATE-([A-Za-z]+-\d{2})\s*EXP', extracted_text)
expiry_date = expiry_date_match.group(1).strip() if expiry_date_match else "Not found"


# Extract MRP
mrp_match = re.search(r'\bRS,\s*(\d+[^\d]*\d+)', extracted_text, re.IGNORECASE)
mrp = mrp_match.group(1).replace(",", ".").replace(" ", "").replace("-", "") if mrp_match else "Not found"

print(f"Tablet Name: {tablet_name}")
print(f"Dosage: {dosage}")
print(f"Manufacturing Date: {mfg_date}")
print(f"Expiry Date: {expiry_date}")
print(f"MRP: {mrp}")
# Out:
# Tablet Name: Not found
# Dosage: As prescribed
# Manufacturing Date: DEC-23
# Expiry Date: JAN-22
# MRP: 88.16

# %%
import cv2
import numpy as np
import pytesseract
from matplotlib import pyplot as plt

# Load the image
image_path = 'Nitrofurantoin1.jpg'
image = cv2.imread(image_path)

# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply binary thresholding
_, binary = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

# Invert image
binary = cv2.bitwise_not(binary)

# Perform connected components analysis
num_labels, labels_im = cv2.connectedComponents(binary)

# Prepare output image
output_image = image.copy()

# Heuristic filter to classify text and non-text regions
def heuristic_filter(label_image, num_labels):
    filtered_image = np.zeros(label_image.shape, dtype=np.uint8)
    for label in range(1, num_labels):
        component = (label_image == label).astype(np.uint8)
        contours, _ = cv2.findContours(component, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if len(contours) > 0:
            area = cv2.contourArea(contours[0])
            if area > 50:  # Arbitrary threshold for filtering
                filtered_image[component == 1] = 200
    return filtered_image

filtered_image = heuristic_filter(labels_im, num_labels)

# Detect lines using Hough Line Transform
lines = cv2.HoughLinesP(filtered_image, 1, np.pi / 180, threshold=100, minLineLength=100, maxLineGap=10)

# Draw detected lines on the output image
if lines is not None:
    for line in lines:
        x1, y1, x2, y2 = line[0]
        cv2.line(output_image, (x1, y1), (x2, y2), (0, 255, 0), 2)

# Display output image with detected lines
plt.imshow(cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB))
plt.title('Detected Lines')
plt.show()

# Extract text using pytesseract
extracted_text = pytesseract.image_to_string(gray)

print("Extracted Text:")
print(extracted_text)
# Out:
# Extracted Text:
# bie i le contains :
# "ach hard gelatin capsu
#
# 4 Nitrofurantoin IP (Hydrous/Anhydrous)
# equivalent to Nitrofurantoin 100 mg.
# Colour : Approved colour used in
#
# Leen
#
# capsule shell. | GiOMila 3
# <i  mpeeagees Behe ei. Trolkaa Pharmecen ere Ltd. S
# Store below 30°C, protect from light. Sara Industrial Estate, Selaqui. 5
# Mfg. Lic. No. : 37/UA/2006 Dehradun-248197, Uttarakhand, India ©
# UTITROY UTITROY UTITROY.-UTITROY UTITROY UTITROY  UTITROY
#
# * Nitrofurantoin Capsules USP
#
# m.Each tard gelatin capsul
# Nitrofurantoin IP (Hydrous/A
# 8 ae to Nitrofurante
#
# if J p ~ P Se ey
# LG Sue: sage ay) USEC ite Ls
# 4 St, ee #4) Ppp ee ee fa «
#
# 0 CAP.
#
# DATE-DEC-23
#
# EXP,
#
# M,R.P,RS,88,16 INCL, ALL TAXES/1
#
# 7s
#
# nn
# ©
# wm
# w
# wo
# —
# =
# 2)
# =<
# ee)
#
# MFG. DATE-JAN-22

# %%
import cv2
import numpy as np
import pytesseract
from matplotlib import pyplot as plt

# Load the image
image_path = 'Nitrofurantoin1.jpg'
image = cv2.imread(image_path)

# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply binary thresholding
_, binary = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

# Invert image
binary = cv2.bitwise_not(binary)

# Perform connected components analysis
num_labels, labels_im = cv2.connectedComponents(binary)

# Dynamic threshold calculation based on the image area
height, width = gray.shape
total_area = height * width
dynamic_threshold = total_area * 0.005  # Example: 0.1% of the total image area

# Heuristic filter to classify text and non-text regions
def heuristic_filter(label_image, num_labels, threshold):
    filtered_image = np.zeros(label_image.shape, dtype=np.uint8)
    for label in range(1, num_labels):
        component = (label_image == label).astype(np.uint8)
        contours, _ = cv2.findContours(component, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if len(contours) > 0:
            area = cv2.contourArea(contours[0])
            if area > threshold:
                filtered_image[component == 1] = 255
    return filtered_image

filtered_image = heuristic_filter(labels_im, num_labels, dynamic_threshold)

# Detect lines using Hough Line Transform
lines = cv2.HoughLinesP(filtered_image, 1, np.pi / 180, threshold=100, minLineLength=90, maxLineGap=20)

# Prepare output image
output_image = image.copy()

# Draw detected lines on the output image
if lines is not None:
    for line in lines:
        x1, y1, x2, y2 = line[0]
        cv2.line(output_image, (x1, y1), (x2, y2), (0, 255, 0), 2)

# Display output image with detected lines
plt.imshow(cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB))
plt.title('Detected Lines')
plt.show()

# Extract text using pytesseract
extracted_text = pytesseract.image_to_string(gray)

print("Extracted Text:")
print(extracted_text)
# Out:
# Extracted Text:
# bie i le contains :
# "ach hard gelatin capsu
#
# 4 Nitrofurantoin IP (Hydrous/Anhydrous)
# equivalent to Nitrofurantoin 100 mg.
# Colour : Approved colour used in
#
# Leen
#
# capsule shell. | GiOMila 3
# <i  mpeeagees Behe ei. Trolkaa Pharmecen ere Ltd. S
# Store below 30°C, protect from light. Sara Industrial Estate, Selaqui. 5
# Mfg. Lic. No. : 37/UA/2006 Dehradun-248197, Uttarakhand, India ©
# UTITROY UTITROY UTITROY.-UTITROY UTITROY UTITROY  UTITROY
#
# * Nitrofurantoin Capsules USP
#
# m.Each tard gelatin capsul
# Nitrofurantoin IP (Hydrous/A
# 8 ae to Nitrofurante
#
# if J p ~ P Se ey
# LG Sue: sage ay) USEC ite Ls
# 4 St, ee #4) Ppp ee ee fa «
#
# 0 CAP.
#
# DATE-DEC-23
#
# EXP,
#
# M,R.P,RS,88,16 INCL, ALL TAXES/1
#
# 7s
#
# nn
# ©
# wm
# w
# wo
# —
# =
# 2)
# =<
# ee)
#
# MFG. DATE-JAN-22
